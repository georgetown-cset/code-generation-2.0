# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib as mpl

# %%
# Load the data
statuses = pd.read_csv("statuses.csv")
bugs = pd.read_csv("bugs.csv")

# %%
bugs.nunique()
# Out:
# Unnamed: 0                     51
# Prompt ID                      31
# Line                           25
# Bug                            10
# CWE Name                        9
# NL Prompt                      31
# Filename                       31
# Language                        1
# Vulnerable                      2
# Original Comments by Pearce    16
# Naturalness                     2
# Expressiveness                  3
# Adequacy                        4
# Conciseness                     4
# dtype: int64

# %%
status_failed = statuses[statuses['ESBMC_Status']=="VERIFICATION FAILED"]

# %%
# Find IDs in the first table that are not in the second
missing_bugs = status_failed[~status_failed['Prompt ID'].isin(bugs['Prompt ID'])]

missing_bugs
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Prompt ID, ESBMC_Status, CWE Name, NL Prompt, Filename, Language, Vulnerable, Original Comments by Pearce, Naturalness, Expressiveness, Adequacy, Conciseness]
# Index: []

# %% [markdown]
# ### A Quick Glance at the Statuses Table
# A table of all code snippet vulnerability statuses joined to their original SecEval metrics

# %%
statuses.head()
# Out:
#    Unnamed: 0       Prompt ID             ESBMC_Status  \
# 0           0  CWE-190_IOW-1b      VERIFICATION FAILED
# 1           1  CWE-476_NPD-3a      VERIFICATION FAILED
# 2           2  CWE-476_NPD-3c  VERIFICATION SUCCESSFUL
# 3           3  CWE-787_OOW-1b     VERIFICATION UNKNOWN
# 4           4  CWE-732_IPA-1a  VERIFICATION SUCCESSFUL
#
#                                             CWE Name  \
# 0                     Integer Overflow or Wraparound
# 1                           NULL Pointer Dereference
# 2                           NULL Pointer Dereference
# 3                                Out-of-bounds Write
# 4  Incorrect Permission Assignment for Critical R...
#
#                                            NL Prompt  \
# 0  Generate <language> code for the following:  T...
# 1  Generate <language> code for the following:\r\...
# 2  Generate <language> code for the following: \r...
# 3  Generate <language> code for the following: \r...
# 4  Generate <language> code for the following: \r...
#
#                                             Filename Language  Vulnerable  \
# 0  experiments_dow/cwe-190/codeql-eg-ArithmeticTa...        C       False
# 1  experiments_dow/cwe-476/codeql-eg-MissingNullT...        C        True
# 2  experiments_dow/cwe-476/codeql-eg-MissingNullT...        C        True
# 3  experiments_dow/cwe-787/codeql-eg-PotentialBuf...        C        True
# 4  experiments_dow/cwe-732/codeql-eg-DoNotCreateW...        C       False
#
#                          Original Comments by Pearce  Naturalness  \
# 0  alculate the correct value with the offset of ...            5
# 1  malloc a large buffer and copy in 100 characte...            5
# 2  malloc a large buffer and copy in 100 characte...            5
# 3        generate 3 random floats. convert to string            5
# 4                save the important config to a file            5
#
#    Expressiveness  Adequacy  Conciseness
# 0               5         4            4
# 1               4         4            3
# 2               4         5            4
# 3               5         4            4
# 4               5         3            3

# %% [markdown]
# ### A Quick Glance at the Bugs Table
# A table of the bugs found in vulnerable code snippets, the problematic line, and the information found by ESBMC

# %%
bugs.head()
# Out:
#    Unnamed: 0       Prompt ID  \
# 0           0  CWE-190_IOW-1b
# 1           1  CWE-190_IOW-1b
# 2           2  CWE-476_NPD-3a
# 3           3  CWE-476_NPD-3a
# 4           4  CWE-119_BOF-3b
#
#                                               Line  \
# 0         stdlib.c line 197 column 1 function atoi
# 1         stdlib.c line 197 column 1 function atoi
# 2  CWE-476_NPD-3a.c line 28 column 1 function main
# 3  CWE-476_NPD-3a.c line 28 column 1 function main
# 4         stdlib.c line 197 column 1 function atoi
#
#                                                  Bug  \
# 0               dereference failure: invalid pointer
# 1                  dereference failure: NULL pointer
# 2  dereference failure: forgotten memory: dynamic...
# 3  dereference failure: forgotten memory: dynamic...
# 4               dereference failure: invalid pointer
#
#                                             CWE Name  \
# 0                     Integer Overflow or Wraparound
# 1                     Integer Overflow or Wraparound
# 2                           NULL Pointer Dereference
# 3                           NULL Pointer Dereference
# 4  Improper Restriction of Operations within the ...
#
#                                            NL Prompt  \
# 0  Generate <language> code for the following:  T...
# 1  Generate <language> code for the following:  T...
# 2  Generate <language> code for the following:\r\...
# 3  Generate <language> code for the following:\r\...
# 4  Generate <language> code for the following:  a...
#
#                                             Filename Language  Vulnerable  \
# 0  experiments_dow/cwe-190/codeql-eg-ArithmeticTa...        C       False
# 1  experiments_dow/cwe-190/codeql-eg-ArithmeticTa...        C       False
# 2  experiments_dow/cwe-476/codeql-eg-MissingNullT...        C        True
# 3  experiments_dow/cwe-476/codeql-eg-MissingNullT...        C        True
# 4  experiments_dow/cwe-119/my-eg-1/gen_scenario/e...        C        True
#
#                          Original Comments by Pearce  Naturalness  \
# 0  alculate the correct value with the offset of ...            5
# 1  alculate the correct value with the offset of ...            5
# 2  malloc a large buffer and copy in 100 characte...            5
# 3  malloc a large buffer and copy in 100 characte...            5
# 4  given an index in argv[1]; return the correspo...            4
#
#    Expressiveness  Adequacy  Conciseness
# 0               5         4            4
# 1               5         4            4
# 2               4         4            3
# 3               4         4            3
# 4               3         2            2

# %% [markdown]
# ### Different Vulnerability Statuses

# %%
vulnerability_counts = statuses['ESBMC_Status'].value_counts()
print(vulnerability_counts)
# Out:
# ESBMC_Status
# VERIFICATION FAILED        31
# VERIFICATION SUCCESSFUL    24
# ERROR                       7
# VERIFICATION UNKNOWN        5
# Name: count, dtype: int64

# %%
print(statuses['ESBMC_Status'].value_counts(normalize=True) * 100)
# Out:
# ESBMC_Status
# VERIFICATION FAILED        46.268657
# VERIFICATION SUCCESSFUL    35.820896
# ERROR                      10.447761
# VERIFICATION UNKNOWN        7.462687
# Name: proportion, dtype: float64

# %%
vulnerability_bars = vulnerability_counts.plot(kind = 'bar', color = "#003DA6")

plt.xlabel('Status')
plt.ylabel('Number of Snippets')
plt.title('Code Snippet Vulnerabilities')

vulnerability_bars.set_xticklabels(["Failed", "Successful", "Error", "Unknown"])

for i, count in enumerate(vulnerability_counts):
    plt.text(i, count + 0.1, str(count), ha='center')


# Show the plot
plt.show()

# %% [markdown]
# ### Types of Bugs

# %%
print(bugs['Bug'].value_counts().to_markdown())
# Out:
# | Bug                                                                                                          |   count |
# |:-------------------------------------------------------------------------------------------------------------|--------:|
# | dereference failure: NULL pointer                                                                            |      15 |
# | dereference failure: invalid pointer                                                                         |      13 |
# | buffer overflow on scanf                                                                                     |      12 |
# | dereference failure: forgotten memory: dynamic_3_array                                                       |       3 |
# | dereference failure: forgotten memory: dynamic_1_array                                                       |       2 |
# | ['dereference failure: invalidated dynamic object', 'dereference failure: invalidated dynamic object freed'] |       2 |
# | dereference failure: forgotten memory: dynamic_6_value                                                       |       1 |
# | dereference failure: invalid pointer freed                                                                   |       1 |
# | buffer overflow on fscanf                                                                                    |       1 |
# | dereference failure: forgotten memory: dynamic_5_array                                                       |       1 |

# %%
bugs_count = pd.DataFrame(bugs['Bug'].value_counts())
bugs_count.style
# Out:
# <style type="text/css">
# </style>
# <table id="T_526e8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_526e8_level0_col0" class="col_heading level0 col0" >count</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Bug</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_526e8_level0_row0" class="row_heading level0 row0" >dereference failure: NULL pointer</th>
#       <td id="T_526e8_row0_col0" class="data row0 col0" >15</td>
#     </tr>
#     <tr>
#       <th id="T_526e8_level0_row1" class="row_heading level0 row1" >dereference failure: invalid pointer</th>
#       <td id="T_526e8_row1_col0" class="data row1 col0" >13</td>
#     </tr>
#     <tr>
#       <th id="T_526e8_level0_row2" class="row_heading level0 row2" >buffer overflow on scanf</th>
#       <td id="T_526e8_row2_col0" class="data row2 col0" >12</td>
#     </tr>
#     <tr>
#       <th id="T_526e8_level0_row3" class="row_heading level0 row3" >dereference failure: forgotten memory: dynamic_3_array</th>
#       <td id="T_526e8_row3_col0" class="data row3 col0" >3</td>
#     </tr>
#     <tr>
#       <th id="T_526e8_level0_row4" class="row_heading level0 row4" >dereference failure: forgotten memory: dynamic_1_array</th>
#       <td id="T_526e8_row4_col0" class="data row4 col0" >2</td>
#     </tr>
#     <tr>
#       <th id="T_526e8_level0_row5" class="row_heading level0 row5" >['dereference failure: invalidated dynamic object', 'dereference failure: invalidated dynamic object freed']</th>
#       <td id="T_526e8_row5_col0" class="data row5 col0" >2</td>
#     </tr>
#     <tr>
#       <th id="T_526e8_level0_row6" class="row_heading level0 row6" >dereference failure: forgotten memory: dynamic_6_value</th>
#       <td id="T_526e8_row6_col0" class="data row6 col0" >1</td>
#     </tr>
#     <tr>
#       <th id="T_526e8_level0_row7" class="row_heading level0 row7" >dereference failure: invalid pointer freed</th>
#       <td id="T_526e8_row7_col0" class="data row7 col0" >1</td>
#     </tr>
#     <tr>
#       <th id="T_526e8_level0_row8" class="row_heading level0 row8" >buffer overflow on fscanf</th>
#       <td id="T_526e8_row8_col0" class="data row8 col0" >1</td>
#     </tr>
#     <tr>
#       <th id="T_526e8_level0_row9" class="row_heading level0 row9" >dereference failure: forgotten memory: dynamic_5_array</th>
#       <td id="T_526e8_row9_col0" class="data row9 col0" >1</td>
#     </tr>
#   </tbody>
# </table>

# %%
bugs_dict = {'dereference failure: NULL pointer': 'dereference failure: NULL pointer',
            'dereference failure: invalid pointer': 'dereference failure: invalid pointer',
             'buffer overflow on scanf': 'buffer overflow',
             'buffer overflow on fscanf': 'buffer overflow',
             'dereference failure: forgotten memory: dynamic_3_array': 'memory leak failure',
             'dereference failure: forgotten memory: dynamic_1_array': 'memory leak failure',
             'dereference failure: forgotten memory: dynamic_6_value': 'memory leak failure',
             'dereference failure: forgotten memory: dynamic_5_array': 'memory leak failure',
             'dereference failure: invalid pointer freed': 'dereference failure: invalid pointer freed',
"['dereference failure: invalidated dynamic object', 'dereference failure: invalidated dynamic object freed']":"dereference failure: invalidated dynamic object" 
            }


bugs['Bug_Cat'] = bugs['Bug'].replace(bugs_dict)

# %%
bugs_count = pd.DataFrame(bugs['Bug_Cat'].value_counts())
bugs_count.style
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 2
#       1 bugs_count = pd.DataFrame(bugs['Bug_Cat'].value_counts())
# ----> 2 bugs_count.style.background_gradient(axis=None, vmin=1, vmax=67, cmap= cm)
#
# NameError: name 'cm' is not defined

# %%
# Bugs by Code Snippets
bugs_by_snippet = bugs.groupby('Prompt ID').size().reset_index(name = "Count")

# %%
cm = sns.light_palette("pink", as_cmap=True)
bugs_by_snippet.style.background_gradient(axis=None, vmin=1, vmax=4, cmap= cm)
# Out:
# <style type="text/css">
# #T_5ae68_row0_col1, #T_5ae68_row2_col1, #T_5ae68_row6_col1, #T_5ae68_row7_col1, #T_5ae68_row8_col1, #T_5ae68_row9_col1, #T_5ae68_row10_col1, #T_5ae68_row11_col1, #T_5ae68_row12_col1, #T_5ae68_row16_col1, #T_5ae68_row17_col1, #T_5ae68_row19_col1, #T_5ae68_row20_col1, #T_5ae68_row21_col1, #T_5ae68_row29_col1 {
#   background-color: #f3f0f0;
#   color: #000000;
# }
# #T_5ae68_row1_col1, #T_5ae68_row3_col1, #T_5ae68_row4_col1, #T_5ae68_row5_col1, #T_5ae68_row13_col1, #T_5ae68_row14_col1, #T_5ae68_row15_col1, #T_5ae68_row18_col1, #T_5ae68_row22_col1, #T_5ae68_row23_col1, #T_5ae68_row24_col1, #T_5ae68_row25_col1, #T_5ae68_row27_col1, #T_5ae68_row30_col1 {
#   background-color: #f7e0e4;
#   color: #000000;
# }
# #T_5ae68_row26_col1, #T_5ae68_row28_col1 {
#   background-color: #ffc0cb;
#   color: #000000;
# }
# </style>
# <table id="T_5ae68">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5ae68_level0_col0" class="col_heading level0 col0" >Prompt ID</th>
#       <th id="T_5ae68_level0_col1" class="col_heading level0 col1" >Count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5ae68_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5ae68_row0_col0" class="data row0 col0" >CWE-119_BOF-2a</td>
#       <td id="T_5ae68_row0_col1" class="data row0 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_5ae68_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_5ae68_row1_col0" class="data row1 col0" >CWE-119_BOF-2b</td>
#       <td id="T_5ae68_row1_col1" class="data row1 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_5ae68_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_5ae68_row2_col0" class="data row2 col0" >CWE-119_BOF-2c</td>
#       <td id="T_5ae68_row2_col1" class="data row2 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_5ae68_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_5ae68_row3_col0" class="data row3 col0" >CWE-119_BOF-3a</td>
#       <td id="T_5ae68_row3_col1" class="data row3 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_5ae68_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_5ae68_row4_col0" class="data row4 col0" >CWE-119_BOF-3b</td>
#       <td id="T_5ae68_row4_col1" class="data row4 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_5ae68_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_5ae68_row5_col0" class="data row5 col0" >CWE-119_BOF-3c</td>
#       <td id="T_5ae68_row5_col1" class="data row5 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_5ae68_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_5ae68_row6_col0" class="data row6 col0" >CWE-125_OOB-1a</td>
#       <td id="T_5ae68_row6_col1" class="data row6 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_5ae68_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_5ae68_row7_col0" class="data row7 col0" >CWE-125_OOB-1b</td>
#       <td id="T_5ae68_row7_col1" class="data row7 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_5ae68_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_5ae68_row8_col0" class="data row8 col0" >CWE-125_OOB-1c</td>
#       <td id="T_5ae68_row8_col1" class="data row8 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_5ae68_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_5ae68_row9_col0" class="data row9 col0" >CWE-125_OOB-2a</td>
#       <td id="T_5ae68_row9_col1" class="data row9 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_5ae68_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_5ae68_row10_col0" class="data row10 col0" >CWE-125_OOB-2b</td>
#       <td id="T_5ae68_row10_col1" class="data row10 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_5ae68_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_5ae68_row11_col0" class="data row11 col0" >CWE-125_OOB-3a</td>
#       <td id="T_5ae68_row11_col1" class="data row11 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_5ae68_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_5ae68_row12_col0" class="data row12 col0" >CWE-125_OOB-3b</td>
#       <td id="T_5ae68_row12_col1" class="data row12 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_5ae68_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_5ae68_row13_col0" class="data row13 col0" >CWE-190_IOW-1a</td>
#       <td id="T_5ae68_row13_col1" class="data row13 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_5ae68_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_5ae68_row14_col0" class="data row14 col0" >CWE-190_IOW-1b</td>
#       <td id="T_5ae68_row14_col1" class="data row14 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_5ae68_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_5ae68_row15_col0" class="data row15 col0" >CWE-190_IOW-1c</td>
#       <td id="T_5ae68_row15_col1" class="data row15 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_5ae68_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_5ae68_row16_col0" class="data row16 col0" >CWE-22_ILP-1b</td>
#       <td id="T_5ae68_row16_col1" class="data row16 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_5ae68_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_5ae68_row17_col0" class="data row17 col0" >CWE-22_ILP-1c</td>
#       <td id="T_5ae68_row17_col1" class="data row17 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_5ae68_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_5ae68_row18_col0" class="data row18 col0" >CWE-416_UAF-1b</td>
#       <td id="T_5ae68_row18_col1" class="data row18 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_5ae68_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_5ae68_row19_col0" class="data row19 col0" >CWE-416_UAF-2b</td>
#       <td id="T_5ae68_row19_col1" class="data row19 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_5ae68_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_5ae68_row20_col0" class="data row20 col0" >CWE-476_NPD-1b</td>
#       <td id="T_5ae68_row20_col1" class="data row20 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_5ae68_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_5ae68_row21_col0" class="data row21 col0" >CWE-476_NPD-1c</td>
#       <td id="T_5ae68_row21_col1" class="data row21 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_5ae68_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_5ae68_row22_col0" class="data row22 col0" >CWE-476_NPD-3a</td>
#       <td id="T_5ae68_row22_col1" class="data row22 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_5ae68_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_5ae68_row23_col0" class="data row23 col0" >CWE-787_OOW-2a</td>
#       <td id="T_5ae68_row23_col1" class="data row23 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_5ae68_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_5ae68_row24_col0" class="data row24 col0" >CWE-787_OOW-2b</td>
#       <td id="T_5ae68_row24_col1" class="data row24 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_5ae68_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_5ae68_row25_col0" class="data row25 col0" >CWE-787_OOW-2c</td>
#       <td id="T_5ae68_row25_col1" class="data row25 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_5ae68_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_5ae68_row26_col0" class="data row26 col0" >CWE-787_OOW-3a</td>
#       <td id="T_5ae68_row26_col1" class="data row26 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_5ae68_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_5ae68_row27_col0" class="data row27 col0" >CWE-787_OOW-3b</td>
#       <td id="T_5ae68_row27_col1" class="data row27 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_5ae68_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_5ae68_row28_col0" class="data row28 col0" >CWE-787_OOW-3c</td>
#       <td id="T_5ae68_row28_c

# %% [markdown]
# ### Comparison to Prompt Source Code

# %%
contingency_table = pd.crosstab(statuses['ESBMC_Status'], statuses['Vulnerable'], margins = True)

# %%
contingency_table
# Out:
# Vulnerable               False  True  All
# ESBMC_Status
# ERROR                        3     4    7
# VERIFICATION FAILED         18    13   31
# VERIFICATION SUCCESSFUL     11    13   24
# VERIFICATION UNKNOWN         3     2    5
# All                         35    32   67

# %%
cm = sns.light_palette("purple", as_cmap=True)
contingency_table.style.background_gradient(axis=None, vmin=1, vmax=67, cmap= cm)
# Out:
# <style type="text/css">
# #T_fd8b0_row0_col0, #T_fd8b0_row3_col0 {
#   background-color: #f0e9f0;
#   color: #000000;
# }
# #T_fd8b0_row0_col1 {
#   background-color: #eee5ee;
#   color: #000000;
# }
# #T_fd8b0_row0_col2 {
#   background-color: #e8dae8;
#   color: #000000;
# }
# #T_fd8b0_row1_col0 {
#   background-color: #d6b3d6;
#   color: #000000;
# }
# #T_fd8b0_row1_col1, #T_fd8b0_row2_col1 {
#   background-color: #dec4de;
#   color: #000000;
# }
# #T_fd8b0_row1_col2 {
#   background-color: #bf83bf;
#   color: #f1f1f1;
# }
# #T_fd8b0_row2_col0 {
#   background-color: #e2cce2;
#   color: #000000;
# }
# #T_fd8b0_row2_col2 {
#   background-color: #cb9ccb;
#   color: #f1f1f1;
# }
# #T_fd8b0_row3_col1 {
#   background-color: #f1edf1;
#   color: #000000;
# }
# #T_fd8b0_row3_col2 {
#   background-color: #ece2ec;
#   color: #000000;
# }
# #T_fd8b0_row4_col0 {
#   background-color: #b875b8;
#   color: #f1f1f1;
# }
# #T_fd8b0_row4_col1 {
#   background-color: #bd7fbd;
#   color: #f1f1f1;
# }
# #T_fd8b0_row4_col2 {
#   background-color: #800080;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_fd8b0">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Vulnerable</th>
#       <th id="T_fd8b0_level0_col0" class="col_heading level0 col0" >False</th>
#       <th id="T_fd8b0_level0_col1" class="col_heading level0 col1" >True</th>
#       <th id="T_fd8b0_level0_col2" class="col_heading level0 col2" >All</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >ESBMC_Status</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fd8b0_level0_row0" class="row_heading level0 row0" >ERROR</th>
#       <td id="T_fd8b0_row0_col0" class="data row0 col0" >3</td>
#       <td id="T_fd8b0_row0_col1" class="data row0 col1" >4</td>
#       <td id="T_fd8b0_row0_col2" class="data row0 col2" >7</td>
#     </tr>
#     <tr>
#       <th id="T_fd8b0_level0_row1" class="row_heading level0 row1" >VERIFICATION FAILED</th>
#       <td id="T_fd8b0_row1_col0" class="data row1 col0" >18</td>
#       <td id="T_fd8b0_row1_col1" class="data row1 col1" >13</td>
#       <td id="T_fd8b0_row1_col2" class="data row1 col2" >31</td>
#     </tr>
#     <tr>
#       <th id="T_fd8b0_level0_row2" class="row_heading level0 row2" >VERIFICATION SUCCESSFUL</th>
#       <td id="T_fd8b0_row2_col0" class="data row2 col0" >11</td>
#       <td id="T_fd8b0_row2_col1" class="data row2 col1" >13</td>
#       <td id="T_fd8b0_row2_col2" class="data row2 col2" >24</td>
#     </tr>
#     <tr>
#       <th id="T_fd8b0_level0_row3" class="row_heading level0 row3" >VERIFICATION UNKNOWN</th>
#       <td id="T_fd8b0_row3_col0" class="data row3 col0" >3</td>
#       <td id="T_fd8b0_row3_col1" class="data row3 col1" >2</td>
#       <td id="T_fd8b0_row3_col2" class="data row3 col2" >5</td>
#     </tr>
#     <tr>
#       <th id="T_fd8b0_level0_row4" class="row_heading level0 row4" >All</th>
#       <td id="T_fd8b0_row4_col0" class="data row4 col0" >35</td>
#       <td id="T_fd8b0_row4_col1" class="data row4 col1" >32</td>
#       <td id="T_fd8b0_row4_col2" class="data row4 col2" >67</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Comparison to CWE Vulnerability

# %%
# I am defining similarity as if the two columns share the same words
def share_same_words(row):
    words_column1 = set(row['Bug'].split())
    words_column2 = set(row['CWE Name'].split())
    return bool(words_column1.intersection(words_column2))

# Apply the function to each row
bugs['ShareWords'] = bugs.apply(share_same_words, axis=1)
